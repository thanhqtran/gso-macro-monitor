# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import xmltodict, json
import matplotlib.pyplot as plt

# %%
url = 'http://nsdp.gso.gov.vn/GSO-chung/SDMXFiles/GSO/GSO.%20Chi%20so%20cong%20nghiep.IIP_Vietnam.xml'
# read xml file from url 
r = requests.get(url)
soup = BeautifulSoup(r.text, 'xml')
# convert xml to python dict
data = xmltodict.parse(str(soup))
data
# Out:
# {'message:StructureSpecificData': {'@xmlns:common': 'http://www.sdmx.org/resources/sdmxml/schemas/v2_1/common',
#   '@xmlns:footer': 'http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message/footer',
#   '@xmlns:message': 'http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message',
#   '@xmlns:ns1': 'urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=IMF:ECOFIN_DSD(1.0):ObsLevelDim:TIME_PERIOD',
#   '@xmlns:ss': 'http://www.sdmx.org/resources/sdmxml/schemas/v2_1/data/structurespecific',
#   '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   '@xsi:schemaLocation': 'http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message https://registry.sdmx.org/schemas/v2_1/SDMXMessage.xsd urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=IMF:ECOFIN_DSD(1.0):ObsLevelDim:TIME_PERIOD https://sdmxcentral.imf.org/ws/public/sdmxapi/rest/schema/datastructure/IMF/ECOFIN_DSD/1.0?format=sdmx-2.1',
#   'message:Header': {'message:ID': 'DS1654054551323',
#    'message:Test': 'false',
#    'message:Prepared': '2022-06-01T03:35:51Z',
#    'message:Sender': {'@id': 'IMF'},
#    'message:Structure': {'@dimensionAtObservation': 'TIME_PERIOD',
#     '@namespace': 'urn:sdmx:org.sdmx.infomodel.datastructure.DataStructure=IMF:ECOFIN_DSD(1.0):ObsLevelDim:TIME_PERIOD',
#     '@structureID': 'IMF_ECOFIN_DSD_1_0',
#     'common:Structure': {'Ref': {'@agencyID': 'IMF',
#       '@id': 'ECOFIN_DSD',
#       '@version': '1.0'}}},
#    'message:DataSetAction': 'Information',
#    'message:Source': {'@xml:lang': 'en', '#text': 'IMF SDMX Central'}},
#   'message:DataSet': {'@COMMENT': 'Published',
#    '@ss:dataScope': 'DataStructure',
#    '@ss:structureRef': 'IMF_ECOFIN_DSD_1_0',
#    '@xsi:type': 'ns1:DataSetType',
#    'Series': [{'@BASE_PER': '2015',
#      '@COUNTERPART_AREA': '_Z',
#      '@DATA_DOMAIN': 'IND',
#      '@FREQ': 'M',
#      '@INDICATOR': 'AIP_ISIC4_IX',
#      '@REF_AREA': 'VN',
#      '@UNIT_MULT': '0',
#      'Obs': [{'@OBS_VALUE': '96.8', '@TIME_PERIOD': '2017-01'},
#       {'@OBS_VALUE': '96.26', '@TIME_PERIOD': '2017-02'},
#       {'@OBS_VALUE': '114.49', '@TIME_PERIOD': '2017-03'},
#       {'@OBS_VALUE': '118.14', '@TIME_PERIOD': '2017-04'},
#       {'@OBS_VALUE': '117.49', '@TIME_PERIOD': '2017-05'},
#       {'@OBS_VALUE': '112.95', '@TIME_PERIOD': '2017-06'},
#       {'@OBS_VALUE': '113.89', '@TIME_PERIOD': '2017-07'},
#       {'@OBS_VALUE': '122.31', '@TIME_PERIOD': '2017-08'},
#       {'@OBS_VALUE': '126.63', '@TIME_PERIOD': '2017-09'},
#       {'@OBS_VALUE': '128.76', '@TIME_PERIOD': '2017-10'},
#       {'@OBS_VALUE': '129.21', '@TIME_PERIOD': '2017-11'},
#       {'@OBS_VALUE': '131.75', '@TIME_PERIOD': '2017-12'},
#       {'@OBS_VALUE': '126.8', '@TIME_PERIOD': '2018-01'},
#       {'@OBS_VALUE': '101.72', '@TIME_PERIOD': '2018-02'},
#       {'@OBS_VALUE': '126.79', '@TIME_PERIOD': '2018-03'},
#       {'@OBS_VALUE': '125.04', '@TIME_PERIOD': '2018-04'},
#       {'@OBS_VALUE': '128.72', '@TIME_PERIOD': '2018-05'},
#       {'@OBS_VALUE': '127.27', '@TIME_PERIOD': '2018-06'},
#       {'@OBS_VALUE': '129.62', '@TIME_PERIOD': '2018-07'},
#       {'@OBS_VALUE': '135.35', '@TIME_PERIOD': '2018-08'},
#       {'@OBS_VALUE': '134.43', '@TIME_PERIOD': '2018-09'},
#       {'@OBS_VALUE': '139.41', '@TIME_PERIOD': '2018-10'},
#       {'@OBS_VALUE': '143.13', '@TIME_PERIOD': '2018-11'},
#       {'@OBS_VALUE': '145.09', '@TIME_PERIOD': '2018-12'},
#       {'@OBS_VALUE': '134.05', '@TIME_PERIOD': '2019-01'},
#       {'@OBS_VALUE': '108.37', '@TIME_PERIOD': '2019-02'},
#       {'@OBS_VALUE': '134.77', '@TIME_PERIOD': '2019-03'},
#       {'@OBS_VALUE': '134.56', '@TIME_PERIOD': '2019-04'},
#       {'@OBS_VALUE': '138.69', '@TIME_PERIOD': '2019-05'},
#       {'@OBS_VALUE': '134.1', '@TIME_PERIOD': '2019-06'},
#       {'@OBS_VALUE': '141.57', '@TIME_PERIOD': '2019-07'},
#       {'@OBS_VALUE': '149.27', '@TIME_PERIOD': '2019-08'},
#       {'@OBS_VALUE': '148.62', '@TIME_PERIOD': '2019-09'},
#       {'@OBS_VALUE': '152.9', '@TIME_PERIOD': '2019-10'},
#       {'@OBS_VALUE': '146.74', '@TIME_PERIOD': '2019-11'},
#       {'@OBS_VALUE': '147.4', '@TIME_PERIOD': '2019-12'},
#       {'@OBS_VALUE': '123.31', '@TIME_PERIOD': '2020-01'},
#       {'@OBS_VALUE': '128.9', '@TIME_PERIOD': '2020-02'},
#       {'@OBS_VALUE': '137.63', '@TIME_PERIOD': '2020-03'},
#       {'@OBS_VALUE': '116.48', '@TIME_PERIOD': '2020-04'},
#       {'@OBS_VALUE': '130.64', '@TIME_PERIOD': '2020-05'},
#       {'@OBS_VALUE': '140.09', '@TIME_PERIOD': '2020-06'},
#       {'@OBS_VALUE': '147.27', '@TIME_PERIOD': '2020-07'},
#       {'@OBS_VALUE': '152.36', '@TIME_PERIOD': '2020-08'},
#       {'@OBS_VALUE': '157.33', '@TIME_PERIOD': '2020-09'},
#       {'@OBS_VALUE': '160.97', '@TIME_PERIOD': '2020-10'},
#       {'@OBS_VALUE': '156.86', '@TIME_PERIOD': '2020-11'},
#       {'@OBS_VALUE': '158.62', '@TIME_PERIOD': '2020-12'},
#       {'@OBS_VALUE': '154.1', '@TIME_PERIOD': '2021-01'},
#       {'@OBS_VALUE': '119.65', '@TIME_PERIOD': '2021-02'},
#       {'@OBS_VALUE': '143.6', '@TIME_PERIOD': '2021-03'},
#       {'@OBS_VALUE': '142.93', '@TIME_PERIOD': '2021-04'},
#       {'@OBS_VALUE': '145.71', '@TIME_PERIOD': '2021-05'},
#       {'@OBS_VALUE': '143.77', '@TIME_PERIOD': '2021-06'},
#       {'@OBS_VALUE': '143.25', '@TIME_PERIOD': '2021-07'},
#       {'@OBS_VALUE': '137.71', '@TIME_PERIOD': '2021-08'},
#       {'@OBS_VALUE': '144.65', '@TIME_PERIOD': '2021-09'},
#       {'@OBS_VALUE': '151.2', '@TIME_PERIOD': '2021-10'},
#       {'@OBS_VALUE': '159.68', '@TIME_PERIOD': '2021-11'},
#       {'@OBS_VALUE': '163.49', '@TIME_PERIOD': '2021-12'},
#       {'@OBS_VALUE': '159.65', '@TIME_PERIOD': '2022-01'},
#       {'@OBS_VALUE': '141.44', '@TIME_PERIOD': '2022-02'},
#       {'@OBS_VALUE': '165.37', '@TIME_PERIOD': '2022-03'},
#       {'@OBS_VALUE': '169.5', '@TIME_PERIOD': '2022-04'},
#       {'@OBS_VALUE': '176.22', '@TIME_PERIOD': '2022-05'}]},
#     {'@BASE_PER': '2015',
#      '@COUNTERPART_AREA': '_Z',
#      '@DATA_DOMAIN': 'IND',
#      '@FREQ': 'M',
#      '@INDICATOR': 'AIP_ISIC4_B_IX',
#      '@REF_AREA': 'VN',
#      '@UNIT_MULT': '0',
#      'Obs': [{'@OBS_VALUE': '85.71', '@TIME_PERIOD': '2017-01'},
#       {'@OBS_VALUE': '85.7', '@TIME_PERIOD': '2017-02'},
#       {'@OBS_VALUE': '104.71', '@TIME_PERIOD': '2017-03'},
#       {'@OBS_VALUE': '97.07', '@TIME_PERIOD': '2017-04'},
#       {'@OBS_VALUE': '99.15', '@TIME_PERIOD': '2017-05'},
#       {'@OBS_VALUE': '96.47', '@TIME_PERIOD': '2017-06'},
#       {'@OBS_VALUE': '86.57', '@TIME_PERIOD': '2017-07'},
#       {'@OBS_VALUE': '80.45', '@TIME_PERIOD': '2017-08'},
#       {'@OBS_VALUE': '82.94', '@TIME_PERIOD': '2017-09'},
#       {'@OBS_VALUE': '95.37', '@TIME_PERIOD': '2017-10'},
#       {'@OBS_VALUE': '90.06', '@TIME_PERIOD': '2017-11'},
#       {'@OBS_VALUE': '91.6', '@TIME_PERIOD': '2017-12'},
#       {'@OBS_VALUE': '100.74', '@TIME_PERIOD': '2018-01'},
#       {'@OBS_VALUE': '81.54', '@TIME_PERIOD': '2018-02'},
#       {'@OBS_VALUE': '99.41', '@TIME_PERIOD': '2018-03'},
#       {'@OBS_VALUE': '95.78', '@TIME_PERIOD': '2018-04'},
#       {'@OBS_VALUE': '97.55', '@TIME_PERIOD': '2018-05'},
#       {'@OBS_VALUE': '94.66', '@TIME_PERIOD': '2018-06'},
#       {'@OBS_VALUE': '87.28', '@TIME_PERIOD': '2018-07'},
#       {'@OBS_VALUE': '78.58', '@TIME_PERIOD': '2018-08'},
#       {'@OBS_VALUE': '82.67', '@TIME_PERIOD': '2018-09'},
#       {'@OBS_VALUE': '89.92', '@TIME_PERIOD': '2018-10'},
#       {'@OBS_VALUE': '92.71', '@TIME_PERIOD': '2018-11'},
#       {'@OBS_VALUE': '95.17', '@TIME_PERIOD': '2018-12'},
#       {'@OBS_VALUE': '95.26', '@TIME_PERIOD': '2019-01'},
#       {'@OBS_VALUE': '78.97', '@TIME_PERIOD': '2019-02'},
#       {'@OBS_VALUE': '102.74', '@TIME_PERIOD': '2019-03'},
#       {'@OBS_VALUE': '97.12', '@TIME_PERIOD': '2019-04'},
#       {'@OBS_VALUE': '99.61', '@TIME_PERIOD': '2019-05'},
#       {'@OBS_VALUE': '93.15', '@TIME_PERIOD': '2019-06'},
#       {'@OBS_VALUE': '87.93', '@TIME_PERIOD': '2019-07'},
#       {'@OBS_VALUE': '85.34', '@TIME_PERIOD': '2019-08'},
#       {'@OBS_VALUE': '82.46', '@TIME_PERIOD': '2019-09'},
#       {'@OBS_VALUE': '92.61', '@TIME_PERIOD': '2019-10'},
#       {'@OBS_VALUE': '86.76', '@TIME_PERIOD': '2019-11'},
#       {'@OBS_VALUE': '90.09', '@TIME_PERIOD': '2019-12'},
#       {'@OBS_VALUE': '81.77', '@TIME_PERIOD': '2020-01'},
#       {'@OBS_VALUE': '88.26', '@TIME_PERIOD': '2020-02'},
#       {'@OBS_VALUE': '92.37', '@TIME_PERIOD': '2020-03'},
#       {'@OBS_VALUE': '86.87', '@TIME_PERIOD': '2020-04'},
#       {'@OBS_VALUE': '88.37', '@TIME_PERIOD': '2020-05'},
#       {'@OBS_VALUE': '85.56', '@TIME_PERIOD': '2020-06'},
#       {'@OBS_VALUE': '88.59', '@TIME_PERIOD': '2020-07'},
#       {'@OBS_VALUE': '78.29', '@TIME_PERIOD': '2020-08'},
#       {'@OBS_VALUE': '78.19', '@TIME_PERIOD': '2020-09'},
#       {'@OBS_VALUE': '81.29', '@TIME_PERIOD': '2020-10'},
#       {'@OBS_VALUE': '76.66', '@TIME_PERIOD': '2020-11'},
#       {'@OBS_VALUE': '84.95', '@TIME_PERIOD': '2020-12'},
#       {'@OBS_VALUE': '87.9', '@TIME_PERIOD': '2021-01'},
#       {'@OBS_VALUE': '72.94', '@TIME_PERIOD': '2021-02'},
#       {'@OBS_VALUE': '85.65', '@TIME_PERIOD': '2021-03'},
#       {'@OBS_VALUE': '86.74', '@TIME_PERIOD': '2021-04'},
#       {'@OBS_VALUE': '84.67', '@TIME_PERIOD': '2021-05'},
#       {'@OBS_VALUE': '82.77', '@TIME_PERIOD': '2021-06'},
#       {'@OBS_VALUE': '81.47', '@TIME_PERIOD': '2021-07'},
#       {'@OBS_VALUE': '76.04', '@TIME_PERIOD': '2021-08'},
#       {'@OBS_VALUE': '71.26', '@TIME_PERIOD': '2021-09'},
#       {'@OBS_VALUE': '70.49', '@TIME_PERIOD': '2021-10'},
#       {'@OBS_VALUE': '76.7', '@TIME_PERIOD': '2021-11'},
#       {'@OBS_VALUE': '87.89', '@TIME_PERIOD': '2021-12'},
#       {'@OBS_VALUE': '78.930000000000007', '@TIME_PERIOD': '2022-01'},
#       {'@OBS_VALUE': '68.16', '@TIME_PERIOD': '2022-02'},
#       {'@OBS_VALUE': '90.37', '@TIME_PERIOD': '2022-03'},
#       {'@OBS_VALUE': '91.03', '@TIME_PERIOD': '2022-04'},
#       {'@OBS_VALUE': '86.56', '@TIME_PERIOD': '2022-05'}]},
#     {'@BASE_PER': '2015',
#      '@COUNTERPART_AREA': '_Z',
#      '@DATA_DOMAIN': 'IND',
#      '@FREQ': 'M',
#      '@INDICATOR': 'AIP_ISIC4_C_IX',
#      '@REF_AREA': 'VN',
#      '@UNIT_MULT': '0',
#      'Obs': [{'@OBS_VALUE': '97.47', '@TIME_PERIOD': '2017-01'},
#       {'@OBS_VALUE': '96.88', '@TIME_PERIOD': '2017-02'},
#       {'@OBS_VALUE': '116.5', '@TIME_PERIOD': '2017-03'},
#       {'@OBS_VALUE': '122.18', '@TIME_PERIOD': '2017-04'},
#       {'@OBS_VALUE': '120.08', '@TIME_PERIOD': '2017-05'},
#       {'@OBS_VALUE': '114.03', '@TIME_PERIOD': '2017-06'},
#       {'@OBS_VALUE': '116.56', '@TIME_PERIOD': '2017-07'},
#       {'@OBS_VALUE': '128.49', '@TIME_PERIOD': '2017-08'},
#       {'@OBS_VALUE': '133.99', '@TIME_PERIOD': '2017-09'},
#       {'@OBS_VALUE': '135.62', '@TIME_PERIOD': '2017-10'},
#       {'@OBS_VALUE': '137.47', '@TIME_PERIOD': '2017-11'},
#       {'@OBS_VALUE': '140.23', '@TIME_PERIOD': '2017-12'},
#       {'@OBS_VALUE': '131.86', '@TIME_PERIOD': '2018-01'},
#       {'@OBS_VALUE': '104.11', '@TIME_PERIOD': '2018-02'},
#       {'@OBS_VALUE': '132.37', '@TIME_PERIOD': '2018-03'},
#       {'@OBS_VALUE': '129.33', '@TIME_PERIOD': '2018-04'},
#       {'@OBS_VALUE': '132.48', '@TIME_PERIOD': '2018-05'},
#       {'@OBS_VALUE': '131.12', '@TIME_PERIOD': '2018-06'},
#       {'@OBS_VALUE': '134.5', '@TIME_PERIOD': '2018-07'},
#       {'@OBS_VALUE': '144.23', '@TIME_PERIOD': '2018-08'},
#       {'@OBS_VALUE': '142.71', '@TIME_PERIOD': '2018-09'},
#       {'@OBS_VALUE': '147.7', '@TIME_PERIOD': '2018-10'},
#       {'@OBS_VALUE': '152.68', '@TIME_PERIOD': '2018-11'},
#       {'@OBS_VALUE': '154.54', '@TIME_PERIOD': '2018-12'},
#       {'@OBS_VALUE': '141.35', '@TIME_PERIOD': '2019-01'},
#       {'@OBS_VALUE': '111.26', '@TIME_PERIOD': '2019-02'},
#       {'@OBS_VALUE': '139.97', '@TIME_PERIOD': '2019-03'},
#       {'@OBS_VALUE': '139.54', '@TIME_PERIOD': '2019-04'},
#       {'@OBS_VALUE': '143.95', '@TIME_PERIOD': '2019-05'},
#       {'@OBS_VALUE': '138.61', '@TIME_PERIOD': '2019-06'},
#       {'@OBS_VALUE': '149.37', '@TIME_PERIOD': '2019-07'},
#       {'@OBS_VALUE': '160.6', '@TIME_PERIOD': '2019-08'},
#       {'@OBS_VALUE': '161.28', '@TIME_PERIOD': '2019-09'},
#       {'@OBS_VALUE': '164.66', '@TIME_PERIOD': '2019-10'},
#       {'@OBS_VALUE': '157.17', '@TIME_PERIOD': '2019-11'},
#       {'@OBS_VALUE': '157.68', '@TIME_PERIOD': '2019-12'},
#       {'@OBS_VALUE': '129.3', '@TIME_PERIOD': '2020-01'},
#       {'@OBS_VALUE': '134.35', '@TIME_PERIOD': '2020-02'},
#       {'@OBS_VALUE': '143.56', '@TIME_PERIOD': '2020-03'},
#       {'@OBS_VALUE': '117.95', '@TIME_PERIOD': '2020-04'},
#       {'@OBS_VALUE': '134.03', '@TIME_PERIOD': '2020-05'},
#       {'@OBS_VALUE': '145.65', '@TIME_PERIOD': '2020-06'},
#       {'@OBS_VALUE': '153.73', '@TIME_PERIOD': '2020-07'},
#       {'@OBS_VALUE': '163.63', '@TIME_PERIOD': '2020-08'},
#       {'@OBS_VALUE': '170.19', '@TIME_PERIOD': '2020-09'},
#       {'@OBS_VALUE': '174.86', '@TIME_PERIOD': '2020-10'},
#       {'@OBS_VALUE': '170.98', '@TIME_PERIOD': '2020-11'},
#       {'@OBS_VALUE': '171.23', '@TIME_PERIOD': '2020-12'},
#       {'@OBS_VALUE': '165.89', '@TIME_PERIOD': '2021-01'},
#       {'@OBS_VALUE': '124.95', '@TIME_PERIOD': '2021-02'},
#       {'@OBS_VALUE': '152.7', '@TIME_PERIOD': '2021-03'},
#       {'@OBS_VALUE': '150.23', '@TIME_PERIOD': '2021-04'},
#       {'@OBS_VALUE': '153.98', '@TIME_PERIOD': '2021-05'},
#       {'@OBS_VALUE': '151.35', '@TIME_PERIOD': '2021-06'},
#       {'@OBS_VALUE': '151.69', '@TIME_PERIOD': '2021-07'},
#       {'@OBS_VALUE': '145.24', '@TIME_PERIOD': '2021-08'},
#       {'@OBS_VALUE': '157.41', '@TIME_PERIOD': '2021-09'},
#       {'@OBS_VALUE': '166.27', '@TIME_PERIOD': '2021-10'},
#       {'@OBS_VALUE': '176.12', '@TIME_PERIOD': '2021-11'},
#       {'@OBS_VALUE': '179.62', '@TIME_PERIOD': '2021-12'},
#       {'@OBS_VALUE': '175.6', '@TIME_PERIOD': '2022-01'},
#       {'@OBS_VALUE': '155.80000000000001', '@TIME_PERIOD': '2022-02'},
#       {'@OBS_VALUE': '180.93', '@TIME_PERIOD': '2022-03'},
#       {'@OBS_VALUE': '185.8', '@TIME_PERIOD': '2022-04'},
#       {'@OBS_VALUE': '194.93', '@TIME_PERIOD': '2022-05'}]},
#     {'@BASE_PER': '2015',
#      '@COUNTERPART_AREA': '_Z',
#      '@DATA_DOMAIN': 'IND',
#      '@FREQ': 'M',
#      '@INDICATOR': 'AIP_ISIC4_D_IX',
#      '@REF_AREA': 'VN',
#      '@UNIT_MULT': '0',
#      'Obs': [{'@OBS_VALUE': '110.62', '@TIME_PERIOD': '2017-01'},
#       {'@OBS_VALUE': '108.89', '@TIME_PERIOD': '2017-02'},
#       {'@OBS_VALUE': '117.5', '@TIME_PERIOD': '2017-03'},
#       {'@OBS_VALUE': '123.8', '@TIME_PERIOD': '2017-04'},
#       {'@OBS_VALUE': '130.85', '@TIME_PERIOD': '2017-05'},
#       {'@OBS_VALUE': '133.93', '@TIME_PERIOD': '2017-06'},
#       {'@OBS_VALUE': '140.84', '@TIME_PERIOD': '2017-07'},
#       {'@OBS_VALUE': '148.4', '@TIME_PERIOD': '2017-08'},
#       {'@OBS_VALUE': '146.67', '@TIME_PERIOD': '2017-09'},
#       {'@OBS_VALUE': '134.78', '@TIME_PERIOD': '2017-10'},
#       {'@OBS_VALUE': '132.59', '@TIME_PERIOD': '2017-11'},
#       {'@OBS_VALUE': '134.92', '@TIME_PERIOD': '2017-12'},
#       {'@OBS_VALUE': '132.84', '@TIME_PERIOD': '2018-01'},
#       {'@OBS_VALUE': '116.74', '@TIME_PERIOD': '2018-02'},
#       {'@OBS_VALUE': '132.36', '@TIME_PERIOD': '2018-03'},
#       {'@OBS_VALUE': '144.01', '@TIME_PERIOD': '2018-04'},
#       {'@OBS_VALUE': '155.18', '@TIME_PERIOD': '2018-05'},
#       {'@OBS_VALUE': '155.03', '@TIME_PERIOD': '2018-06'},
#       {'@OBS_VALUE': '166.34', '@TIME_PERIOD': '2018-07'},
#       {'@OBS_VALUE': '164.84', '@TIME_PERIOD': '2018-08'},
#       {'@OBS_VALUE': '160.23', '@TIME_PERIOD': '2018-09'},
#       {'@OBS_VALUE': '162.37', '@TIME_PERIOD': '2018-10'},
#       {'@OBS_VALUE': '157.7', '@TIME_PERIOD': '2018-11'},
#       {'@OBS_VALUE': '159.27', '@TIME_PERIOD': '2018-12'},
#       {'@OBS_VALUE': '144.93', '@TIME_PERIOD': '2019-01'},
#       {'@OBS_VALUE': '135.78', '@TIME_PERIOD': '2019-02'},
#       {'@OBS_VALUE': '152.11', '@TIME_PERIOD': '2019-03'},
#       {'@OBS_VALUE': '162.47', '@TIME_PERIOD': '2019-04'},
#       {'@OBS_VALUE': '167.69', '@TIME_PERIOD': '2019-05'},
#       {'@OBS_VALUE': '170.87', '@TIME_PERIOD': '2019-06'},
#       {'@OBS_VALUE': '175.28', '@TIME_PERIOD': '2019-07'},
#       {'@OBS_VALUE': '172.85', '@TIME_PERIOD': '2019-08'},
#       {'@OBS_VALUE': '162.61', '@TIME_PERIOD': '2019-09'},
#       {'@OBS_VALUE': '165.02', '@TIME_PERIOD': '2019-10'},
#       {'@OBS_VALUE': '167.83', '@TIME_PERIOD': '2019-11'},
#       {'@OBS_VALUE': '164.11', '@TIME_PERIOD': '2019-12'},
#       {'@OBS_VALUE': '146.25', '@TIME_PERIOD': '2020-01'},
#       {'@OBS_VALUE': '154.21', '@TIME_PERIOD': '2020-02'},
#       {'@OBS_VALUE': '170.08', '@TIME_PERIOD': '2020-03'},
#       {'@OBS_VALUE': '155.42', '@TIME_PERIOD': '2020-04'},
#       {'@OBS_VALUE': '177.49', '@TIME_PERIOD': '2020-05'},
#       {'@OBS_VALUE': '190.79', '@TIME_PERIOD': '2020-06'},
#       {'@OBS_VALUE': '199.35', '@TIME_PERIOD': '2020-07'},
#       {'@OBS_VALUE': '192.39', '@TIME_PERIOD': '2020-08'},
#       {'@OBS_VALUE': '192.8', '@TIME_PERIOD': '2020-09'},
#       {'@OBS_VALUE': '189.93', '@TIME_PERIOD': '2020-10'},
#       {'@OBS_VALUE': '184.01', '@TIME_PERIOD': '2020-11'},
#       {'@OBS_VALUE': '186.66', '@TIME_PERIOD': '2020-12'},
#       {'@OBS_VALUE': '175.51', '@TIME_PERIOD': '2021-01'},
#       {'@OBS_VALUE': '155.44', '@TIME_PERIOD': '2021-02'},
#       {'@OBS_VALUE': '171.83', '@TIME_PERIOD': '2021-03'},
#       {'@OBS_VALUE': '181.59', '@TIME_PERIOD': '2021-04'},
#       {'@OBS_VALUE': '186.8', '@TIME_PERIOD': '2021-05'},
#       {'@OBS_VALUE': '189.84', '@TIME_PERIOD': '2021-06'},
#       {'@OBS_VALUE': '183.53', '@TIME_PERIOD': '2021-07'},
#       {'@OBS_VALUE': '184.1', '@TIME_PERIOD': '2021-08'},
#       {'@OBS_VALUE': '169', '@TIME_PERIOD': '2021-09'},
#       {'@OBS_VALUE': '170.52', '@TIME_PERIOD': '2021-10'},
#       {'@OBS_VALUE': '172.96', '@TIME_PERIOD': '2021-11'},
#       {'@OBS_VALUE': '165.47', '@TIME_PERIOD': '2021-12'},
#       {'@OBS_VALUE': '172.94', '@TIME_PERIOD': '2022-01'},
#       {'@OBS_VALUE': '152.34', '@TIME_PERIOD': '2022-02'},
#       {'@OBS_VALUE': '175.43', '@TIME_PERIOD': '2022-03'},
#       {'@OBS_VALUE': '177.64', '@TIME_PERIOD': '2022-04'},
#       {'@OBS_VALUE': '185.8', '@TIME_PERIOD': '2022-05'}]},
#     {'@BASE_PER': '2015',
#      '@COUNTERPART_AREA': '_Z',
#      '@DATA_DOMAIN': 'IND',
#      '@FREQ': 'M',
#      '@INDICATOR': 'AIP_ISIC4_E_IX',
#      '@REF_AREA': 'VN',
#      '@UNIT_MULT': '0',
#      'Obs': [{'@OBS_VALUE': '98.09', '@TIME_PERIOD': '2017-01'},
#       {'@OBS_VALUE': '100.94', '@TIME_PERIOD': '2017-02'},
#       {'@OBS_VALUE': '100.63', '@TIME_PERIOD': '2017-03'},
#       {'@OBS_VALUE': '106.04', '@TIME_PERIOD': '2017-04'},
#       {'@OBS_VALUE': '102.65', '@TIME_PERIOD': '2017-05'},
#       {'@OBS_VALUE': '107.97', '@TIME_PERIOD': '2017-06'},
#       {'@OBS_VALUE': '107.76', '@TIME_PERIOD': '2017-07'},
#       {'@OBS_VALUE': '110.44', '@TIME_PERIOD': '2017-08'},
#       {'@OBS_VALUE': '107.09', '@TIME_PERIOD': '2017-09'},
#       {'@OBS_VALUE': '107.08', '@TIME_PERIOD': '2017-10'},
#       {'@OBS_VALUE': '111.18', '@TIME_PERIOD': '2017-11'},
#       {'@OBS_VALUE': '114.21', '@TIME_PERIOD': '2017-12'},
#       {'@OBS_VALUE': '114.39', '@TIME_PERIOD': '2018-01'},
#       {'@OBS_VALUE': '105.55', '@TIME_PERIOD': '2018-02'},
#       {'@OBS_VALUE': '105.1', '@TIME_PERIOD': '2018-03'},
#       {'@OBS_VALUE': '107.72', '@TIME_PERIOD': '2018-04'},
#       {'@OBS_VALUE': '113.05', '@TIME_PERIOD': '2018-05'},
#       {'@OBS_VALUE': '114.2', '@TIME_PERIOD': '2018-06'},
#       {'@OBS_VALUE': '114.79', '@TIME_PERIOD': '2018-07'},
#       {'@OBS_VALUE': '116.04', '@TIME_PERIOD': '2018-08'},
#       {'@OBS_VALUE': '114.81', '@TIME_PERIOD': '2018-09'},
#       {'@OBS_VALUE': '116.96', '@TIME_PERIOD': '2018-10'},
#       {'@OBS_VALUE': '118.29', '@TIME_PERIOD': '2018-11'},
#       {'@OBS_VALUE': '121.66', '@TIME_PERIOD': '2018-12'},
#       {'@OBS_VALUE': '119.02', '@TIME_PERIOD': '2019-01'},
#       {'@OBS_VALUE': '111.57', '@TIME_PERIOD': '2019-02'},
#       {'@OBS_VALUE': '113.76', '@TIME_PERIOD': '2019-03'},
#       {'@OBS_VALUE': '117.55', '@TIME_PERIOD': '2019-04'},
#       {'@OBS_VALUE': '119.3', '@TIME_PERIOD': '2019-05'},
#       {'@OBS_VALUE': '123.91', '@TIME_PERIOD': '2019-06'},
#       {'@OBS_VALUE': '122.54', '@TIME_PERIOD': '2019-07'},
#       {'@OBS_VALUE': '124.83', '@TIME_PERIOD': '2019-08'},
#       {'@OBS_VALUE': '138.12', '@TIME_PERIOD': '2019-09'},
#       {'@OBS_VALUE': '136.23', '@TIME_PERIOD': '2019-10'},
#       {'@OBS_VALUE': '138.24', '@TIME_PERIOD': '2019-11'},
#       {'@OBS_VALUE': '144.26', '@TIME_PERIOD': '2019-12'},
#       {'@OBS_VALUE': '124.63', '@TIME_PERIOD': '2020-01'},
#       {'@OBS_VALUE': '129.7', '@TIME_PERIOD': '2020-02'},
#       {'@OBS_VALUE': '128.75', '@TIME_PERIOD': '2020-03'},
#       {'@OBS_VALUE': '122.91', '@TIME_PERIOD': '2020-04'},
#       {'@OBS_VALUE': '129.45', '@TIME_PERIOD': '2020-05'},
#       {'@OBS_VALUE': '137.61', '@TIME_PERIOD': '2020-06'},
#       {'@OBS_VALUE': '136.29', '@TIME_PERIOD': '2020-07'},
#       {'@OBS_VALUE': '138.63', '@TIME_PERIOD': '2020-08'},
#       {'@OBS_VALUE': '145.68', '@TIME_PERIOD': '2020-09'},
#       {'@OBS_VALUE': '143.29', '@TIME_PERIOD': '2020-10'},
#       {'@OBS_VALUE': '143.59', '@TIME_PERIOD': '2020-11'},
#       {'@OBS_VALUE': '146.38', '@TIME_PERIOD': '2020-12'},
#       {'@OBS_VALUE': '143.04', '@TIME_PERIOD': '2021-01'},
#       {'@OBS_VALUE': '135.39', '@TIME_PERIOD': '2021-02'},
#       {'@OBS_VALUE': '136.76', '@TIME_PERIOD': '2021-03'},
#       {'@OBS_VALUE': '143.66', '@TIME_PERIOD': '2021-04'},
#       {'@OBS_VALUE': '135.74', '@TIME_PERIOD': '2021-05'},
#       {'@OBS_VALUE': '138.07', '@TIME_PERIOD': '2021-06'},
#       {'@OBS_VALUE': '137.15', '@TIME_PERIOD': '2021-07'},
#       {'@OBS_VALUE': '138.49', '@TIME_PERIOD': '2021-08'},
#       {'@OBS_VALUE': '142.73', '@TIME_PERIOD': '2021-09'},
#       {'@OBS_VALUE': '142.53', '@TIME_PERIOD': '2021-10'},
#       {'@OBS_VALUE': '144.65', '@TIME_PERIOD': '2021-11'},
#       {'@OBS_VALUE': '152.99', '@TIME_PERIOD': '2021-12'},
#       {'@OBS_VALUE': '144.56', '@TIME_PERIOD': '2022-01'},
#       {'@OBS_VALUE': '139.76', '@TIME_PERIOD': '2022-02'},
#       {'@OBS_VALUE': '130.16999999999999', '@TIME_PERIOD': '2022-03'},
#       {'@OBS_VALUE': '145.04', '@TIME_PERIOD': '2022-04'},
#       {'@OBS_VALUE': '142.53', '@TIME_PERIOD': '2022-05'}]}]}}}

# %%
structure = {0: {'AIP_ISIC4_IX':'Industry (2015=100)'}, 1:{'AIP_ISIC4_B_IX':'Mining and Quarying (2015=100)'}, 2:{'AIP_ISIC4_C_IX':'Manufacturing (2015=100)'}, 3:{'AIP_ISIC4_D_IX':'Electricity, Gas (2015=100)'}, 4:{'AIP_ISIC4_E_IX':'Water Supply: Sewerage, Waste Mgt/Remediation Activities(2015=100)'}}
data_series = data['message:StructureSpecificData']['message:DataSet']['Series']
df_industry = data_series[0]
df_mining = data_series[1]
df_manufacturing = data_series[2]
df_electricity = data_series[3]
df_water = data_series[4]

# %%
def get_industry_data(dataframe):
   x_dict = []
   y_dict = []
   for i in range(0,len(dataframe['Obs'])):
      x = dataframe['Obs'][i]['@TIME_PERIOD'] 
      y = dataframe['Obs'][i]['@OBS_VALUE']
      x = pd.to_datetime(x).strftime('%Y-%m') #convert x to datetime
      x_dict.append(x)
      y_dict.append(float(y)) #convert y to float
   return x_dict, y_dict

# %%
fig, ax = plt.subplots(figsize=(10,5))
fontsize = 14
# plot data
# barplot for industry 
plt.bar(get_industry_data(df_industry)[0], get_industry_data(df_industry)[1], color='#ff7f0e', width=0.5, label='All Industry', alpha=0.2)
#plt.plot(get_industry_data(df_industry)[0], get_industry_data(df_industry)[1], label='All Industry', ls='-', marker='o', color='blue')
plt.plot(get_industry_data(df_manufacturing)[0], get_industry_data(df_manufacturing)[1], label='Manufacturing')
plt.plot(get_industry_data(df_electricity)[0], get_industry_data(df_electricity)[1], label='Electricity, Gas')
plt.plot(get_industry_data(df_water)[0], get_industry_data(df_water)[1], label='Water/Sewage')
plt.plot(get_industry_data(df_mining)[0], get_industry_data(df_mining)[1], label='Mining and Quarying')
#legend outside 
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1, fontsize=fontsize)
#set x-ticks every 3 months 
ax.xaxis.set_major_locator(plt.MultipleLocator(4))
plt.xlabel('Month', fontsize=fontsize)
plt.xticks(rotation=60, fontsize=12)
plt.ylabel('Index, 2015=100', fontsize=fontsize)
plt.title('Vietnam Industrial Production Index (monthly)', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Vietnam Industrial Production Index (monthly)')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import imageio
# ======== gif for iip ======================
filenames = []
x = get_industry_data(df_industry)[0]
for i in range(0, len(x)):
    fig, ax = plt.subplots(figsize=(10,5))
    fontsize = 14
    # plot data
    plt.bar(get_industry_data(df_industry)[0][:i], get_industry_data(df_industry)[1][:i], color='#ff7f0e', width=0.5, label='All Industry', alpha=0.2)
    #plt.plot(get_industry_data(df_industry)[0][:i], get_industry_data(df_industry)[1][:i], label='All Industry', ls='-', marker='o', color='blue')
    plt.plot(get_industry_data(df_manufacturing)[0][:i], get_industry_data(df_manufacturing)[1][:i], label='Manufacturing')
    plt.plot(get_industry_data(df_electricity)[0][:i], get_industry_data(df_electricity)[1][:i], label='Electricity, Gas')
    plt.plot(get_industry_data(df_water)[0][:i], get_industry_data(df_water)[1][:i], label='Water/Sewage')
    plt.plot(get_industry_data(df_mining)[0][:i], get_industry_data(df_mining)[1][:i], label='Mining and Quarying')
    #legend outside 
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), ncol=1, fontsize=fontsize)
    #set x-ticks every 3 months 
    ax.xaxis.set_major_locator(plt.MultipleLocator(4))
    plt.xlabel('Month', fontsize=fontsize)
    plt.xticks(rotation=45, fontsize=10)
    plt.ylabel('Index, 2015=100', fontsize=fontsize)
    plt.title('Vietnam Industrial Production Index (monthly)', fontsize=16)
    
    # create file name and append it to a list
    filename = f'{i}.png'
    filenames.append(filename)
    
    # save frame
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()
# build gif

gif_filename = 'iip.gif'
images = []

for filename in filenames:
    images.append(imageio.imread(filename))
duration = 0.15
imageio.mimsave(gif_filename, images, duration=duration, loop=1)
       
# Remove files
for filename in set(filenames):
    os.remove(filename)
